# %% [markdown]
# # Final Project Proposal
#
# ### Brian Livian, Ke Chen, Alejandra Zapata

# %% [markdown]
# ## Introduction
#
# Soccer is one of the few sports that gathers millions of people across the world and is internationally acclaimed. It is also one of the sports in the top 10 list of "Highest Paid Sports", and has some of the most popular players on the list of "Highest Paid Athletes". Soccer players often attract million dollar deals when joining teams as well as marketing campaigns given that according to "World Atlas" it is the most popular sport in the world. On this project, our team will aim to analyze the factors that drive soccer player wages and use real data to predict the wages. Through the project we will try to understand what are the most valued characteristics on a player that may be a key piece on their value and wage.

# %% [markdown]
# ## Research Question
#
# **1. Can the player stats of a soccer player accurately indicate their wage and/or value?**
#
# We know soccer is sport that attracts a lot of money but is drive by the fame of outstanding players so by answering this question on merely game stats we can use it as an indicator of bias on wages. Perhaps a player with good stats does not always get the same wage as another player with similar stats but lower international recognition and fame.
#
# **2. By creating predictive models, can we determine whether a player is overpaid or underpaid?**
#
# Based on our research, experts argue that wages are driven by supply and demand. The talent is scarce and lots of teams want talented players. This logic indicates that better players get paid well which is true for really popular players but what data can we discover when we look at all players across the table?

# %% [markdown]
# ## Data to be Used
#
# For the project we will be using the FIFA's track of records with ove 18000 observations, one for each player. The dataset provides the statistics for each player as well as their physical features relevant to their performance which are all depicted through numeric data. Moreover, the dataset includes categorical data that indicates the player's nationality, preferred foot, current team and position. We will use this data to create three predictive models and answer the below questions.

# %%
import pandas as pd
df = pd.read_csv('https://raw.githubusercontent.com/AlejandraZS10/final_project/master/data.csv')  
df.head(10)
# Out:
#    Unnamed: 0      ID               Name  Age  \
# 0           0  158023           L. Messi   31
# 1           1   20801  Cristiano Ronaldo   33
# 2           2  190871          Neymar Jr   26
# 3           3  193080             De Gea   27
# 4           4  192985       K. De Bruyne   27
# 5           5  183277          E. Hazard   27
# 6           6  177003          L. Modrić   32
# 7           7  176580          L. Suárez   31
# 8           8  155862       Sergio Ramos   32
# 9           9  200389           J. Oblak   25
#
#                                             Photo Nationality  \
# 0  https://cdn.sofifa.org/players/4/19/158023.png   Argentina
# 1   https://cdn.sofifa.org/players/4/19/20801.png    Portugal
# 2  https://cdn.sofifa.org/players/4/19/190871.png      Brazil
# 3  https://cdn.sofifa.org/players/4/19/193080.png       Spain
# 4  https://cdn.sofifa.org/players/4/19/192985.png     Belgium
# 5  https://cdn.sofifa.org/players/4/19/183277.png     Belgium
# ...

# %% [markdown]
# ## Approach
#
# #### Feature Selection
#
# Our data has 89 attributes that describe the players which speaks to the complexity of the sport. As part of our approach we will use thorough reasearch and domain knowledge acquisition as well as feature selection strategies and algorithems to narrow down numeric variables.
#
# #### Modeling
#
# We will use *Multiple Linear Regression* to determine if a player's stats can accurately determine their wage and/or value. After narrowing down the number of features, we will also find the least amount of information one may need to know about a player to determine its value.
#
# Our project will use *Support Vector Machine Regression* to determine if a player's stats, nationaly, club, or other features we will discover, can help predict the wage and/or value of similar players.
#
# Furthermore, we will use the regression algorithm *Polynomial Regression* with the numeric data in order to find a model with better results.
#
# #### Ensembling
#
# The aforementiones models will inform our ensemble model by outputing the predicted value of the wage. We will use a boosting method of ensemble such as to build on the model's learnings and find the most accuracy. Research has indicated how better players get paid higher but other sources have shown how the Club and popularity can be an influence. Our model will have a holistic approach by first implementing the regression with just the player's stats and incorporating some of the categorical variables when appropiate.

# %% [markdown]
# ## Sources
#
# 1. https://mastersoccermind.com/why-are-soccer-players-paid-so-much/
# 2. https://www.ispo.com/en/people/forbes-ranking-roger-federer-highest-paid-athlete-2020

# %% [markdown]
# ## Appendix
#
# Our team is still doing research on the best implementation of models and how to classify so the approach is subject to change as we approach the end of the semester.
#
# Our team has a strong interest on Neural Networks and is interested on implementing it into the project if useful to the prediction.
